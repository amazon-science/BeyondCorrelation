# %%
import sys

sys.path.append("../beyond_correlation")

# %%
from beyond_correlation.beyond_correlation_compare import beyond_correlation_for_ordinal_data
import numpy as np

# Randomly generate human labels for 100 examples, each with 3 annotation.
# You should replace this with your own data. 
# The ordinal data is in 1-5.
human_labels = np.random.randint(1, 6, size=(100, 3)).tolist()

# Randomly generate machine labels for 100 examples, each with 5 annotation.
# You should replace this with your own data.
machine_labels = np.random.randint(1, 6, size=(100, 5)).tolist()

beyond_correlation_for_ordinal_data(human_labels=human_labels,
                                    machine_labels=machine_labels,
                                    ordinal_min=1,
                                    ordinal_max=5,
                                    result_dir="../toy_example_ordinal",
                                    experiment_name="toy_example",
                                    )
# Out:
# /Users/leixx/miniconda3/envs/research/lib/python3.10/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#                                               name  proportion  size  \
# 0                                              All       100.0   100
# 1  human_labels_num_unique = 1 (perfect agreement)         2.0     2
# 2                      human_labels_num_unique = 2        54.0    54
# 3                      human_labels_num_unique = 3        44.0    44
# 4                      human_labels_num_unique = 4         0.0     0
# 5                      human_labels_num_unique = 5         0.0     0
# 6       0 <= human_labels_median_percent_vote < 60        44.0    44
# 7      60 <= human_labels_median_percent_vote < 80        54.0    54
# 8     80 <= human_labels_median_percent_vote < 100         0.0     0
#
# ...

# %%
from beyond_correlation.beyond_correlation_compare import beyond_correlation_for_categorical_data

# Randomly generate human labels for 100 examples, each with 3 annotation.
# You should replace this with your own data. 
# The categorical data has 3 labels, A, B and C.
human_labels = np.random.choice(["A", "B", "C"], size=(100, 3), replace=True).tolist()

# Randomly generate machine labels for 100 examples, each with 5 annotation.
# You should replace this with your own data.
machine_labels = np.random.choice(["A", "B", "C"], size=(100, 5), replace=True).tolist()

beyond_correlation_for_categorical_data(human_labels=human_labels,
                                        machine_labels=machine_labels,
                                        unique_label_list=["A", "B", "C"],
                                        result_dir="../toy_example_ordinal",
                                        experiment_name="toy_example",
                                        )
# Out:
#                                                 name  proportion  size  \
# 0                                                All       100.0   100
# 1  Number of unique human labels (u=1) (perfect a...         9.0     9
# 2                Number of unique human labels (u=2)        66.0    66
# 3                Number of unique human labels (u=3)        25.0    25
# 4              0% <= Human label majority vote < 60%        25.0    25
# 5             60% <= Human label majority vote < 80%        66.0    66
# 6            80% <= Human label majority vote < 100%         0.0     0
#
#    krippendorff_HH  krippendorff_MM  krippendorff_H-majority_M-majority  \
# 0        -0.046940         0.002886                            0.041180
# 1         1.000000        -0.020958                           -0.252632
# 2        -0.006035         0.014115                            0.094522
# 3        -0.480000        -0.017084                           -0.001202
# ...
